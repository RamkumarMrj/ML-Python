# %% [markdown]
# # 100 Days of Machine Learning - Daily Task
# Python Practice Code for ML

# %% [markdown]
# # Week 1 Tasks
# Python Basic Function Practiced Pad

# %% [markdown]
# #*Day_1*
# From Youtube PlayList :
# https://www.youtube.com/watch?v=oVp1vrfL_w4&list=PLQVvvaa0QuDe8XSftW-RAxdo6OmaeL85M
#
#
# #1. Difference Between Python2 and Python3 :
#
# **Python 3**
#
# def main():
#   print("Hello World!")
#
# if __name__== "__main__":
#   main()
#
# **Python 2**
#
# def main():
#   print "Hello World!"
#
# if __name__== "__main__":
#   main()
#
#
# #2. Install/use both Python 2 and Python 3
#
# #3. Print Function and Strings
#
# Example:
# print("hello \n world")
# print('variable', + int('8') + 5 'another' )
#
#
# #4. Math
#
# + - / * ** % ..etc
#
#
# #5. Variables
#
# 1. String(str)  -  Non GUI
# 2. Int (int)  -  Non GUI
# 3. float
#
# GUI
# 1. StringVar()  -  String
# 2. IntVar()  -  Integer
#
# Swapp function :
# x,y = x,y
#
#
# #6. While Loop:
#
# Condition = 1
# while condition < 10:
#   print(condition)
#   condition = condition + 1
#   or
#   condtion += 1
#
# while True:
#   print("infinite loop")
#
#
# #7. For loop :
#
# list1 = [ 1, 3, 4, 6, 90]
# for i in list1:
#   print(i)
#
# for i in range(1,11):
#   print(x)
#
# for i in range(start:step:stop):
#   print(i)
#
# #8. If Statement :
# < > == <= >=  !=
# and or not
# and other bitwise operators
#
# if x>y:
#   print("x is high")
#
# if z < y > x:
#   print('y is greater than z and x')
#
# if z < y > x > a:
#   print('y is greater than z and x')
#
#
# #9. If else Statement :
#
# if x>y:
#   print("x is high")
# if x>10:
#   print("x is high")
# else:
#   print("y is high")
#
#
# #10. If elif else Statement :
#
# if x>y:
#   print("x is high")
# elif x>10:
#   print("x is high")
# elif y>10:
#   print("y is high")
# else:
#   print("y is high")
#
#
# #11. Functions :
#
# def foo():
#   print('basic of function')
#   a = b + c
#   print(a)
#
#
# #12. Function Parameters :
#
# def sample_add(n1,n2):
#   ans = n1 + n2
#   print(ans)
#
# sample_add(10,2)
#
#
# #13. Functions Parameter Defaults :
#
# def sample(num1,mun2):
#   pass
#
# def sample(n1,n2=5):
#   print(n1,n2)
#
# sample(2)
#
# def basic(w,h,f='TNR',bgc='w'.scrollbar=True):
#   print(w,h,f,bgc)
#
# basic(500,350,bgc='b')
#
#
# #14. Gloabal and Local Variable :
#
# x = 6
# def ex():
#   z = 5
#   print(z)
#   print(x+5)
#   x+=6 #Error Unbound Local Variable
# ex()
#
# x = 6
# def ex():
#   global x # Making as Global Variable x
#   print(x)
#   x+=5
#   print(x)
#
# ex()
#
# x = 6
# def ex():
#   globx = x
#   print(globx)
#   globx+=5
#   print(globx)
#   return globx
#
# ex()
# print(x)
#
#
# #15. Installing Modues :
#
# Linux Terminal :
# $ sudo apt-get install python-matploitlib
#
# Manula Installation:
#   Download Packege from site -> Extract
#   Open Cmd on same location *# setup.py install*
#
#
# #16. Download and install python packages and modules with pip :
#
# Ex: pip install wget
#
#
# #17. Common Error :
#
# Examples :
#   NameError, Expected intendation, str to int conversion...etc
#
#
# #18. Writing to file :
#
# txt = 'Sample text for writing to file \n sample code;'
# saveFile = open('exfile.txt','w')
# saveFile.write(txt)
# saveFile.close()  # will create exfile.txt file
#
#
# #19. Appending Files :
#
# appnme = '\nNew bit'
# appnme = open('exfile.txt','a')
# appnme.write(appnme)
# appnme.close()
#
#
# #20 Read from file :
#
# readme = open('exfile.txt','r').readline()
# print(readme)
#
#
# #21 Classes :
#
# class calc:
#   def add(a,b):
#     add = a + b
#     print(add)
#   def sub(a,b):
#     sub = a - b
#     print(sub)
#   def mul(a,b):
#     mul = a + b
#     print(mul)
#   def div(a,b):
#     div = a + b
#     print(div)
# calc.mul(2,5)
#
#
# #22 FAQ :
#
# About: #!/usr/bin/python
# '''Save as epic.py'''
# def ep():
#   print('great..!')
#
# if __name__ == '__main__':
#   print('Module..!!')
# '''import from another file by :'''
# import epic
# epic.ep()
#
#
# #23. Getting User input :
#
# get = input('Enter your Name :')
# print('Hello', get)
#
#
# #24. Statistics(Mean, Standard Deviation) :
#
# import statistics
# ex_list = [2,3,5,7,8,9,5,]
# x = statistics.mean(ex_list)
# prin(x)
#
#
# #25. Module import syntax :
#
# '''import statistics as s
# from statistics import variance as v
# from statistics import variance as v, mean as m'''
# from statistics import *
# ex_list = [2,3,5,7,8,9,5,]
# x = s.variance(ex_list)
# y = mean(ex_list)
# prin(x)
#
#
# #26. Making Modules :
#
# '''save as files.py'''
# def ex(data):
#   print(data)
#
# '''type another python'''
# import files
# files.ex('test')
